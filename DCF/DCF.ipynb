# %%
from DCF.dcf_model import DCFModel
from DCF.enhanced_model import EnhancedDCFModel
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Lite Version

# %%
model = DCFModel('0175.HK')
model.fetch_financials()
model.fetch_market_data()

# %%
assumptions = {
    # 'revenue_growth': 0.2,   # 8% for next 5 years
    # 'op_margin': 0.3,
    # 'tax_rate': 0.16,
    # 'capex_pct_rev': 0.03,
    # 'nwc_pct_rev': 0.02,
    # 'terminal_growth': 0.035,
    'erp': 0.05,
}
model.set_assumptions(assumptions)

# %%
price = model.valuation()
print(pd.DataFrame([model.assumptions]).T)
print(f"Implied share price: ${price:.2f}")
model.sensitivity_analysis(np.arange(0.08, 0.11, 0.005), np.arange(0.03, 0.04, 0.005))
# Out:
#                         0
# revenue_growth   0.336999
# op_margin        0.055621
# tax_rate         0.046068
# da_pct_rev       0.045052
# capex_pct_rev    0.066557
# nwc_pct_rev      0.050000
# cost_debt        0.066792
# erp              0.050000
# terminal_growth  0.030000
# wacc             0.081627
# Implied share price: $31.65
#            0.030      0.035      0.040
# 0.080  32.647334  35.591969  39.272762
# 0.085  29.759533  32.124676  35.015405
# 0.090  27.356707  29.291743  31.613786
# 0.095  25.326856  26.934493  28.834427
# 0.100  23.589981  24.943072  26.521677
# 0.105   22.08742  23.239017  24.567783

# %% [markdown]
# ### Sophisticated Version

# %%
enhanced_model = EnhancedDCFModel('AAPL')
# Out:
# WARNING: Using default 4.0% risk-free rate
# Good earnings quality: nan% unusual items

# %%
# Generate full report
enhanced_model.generate_report()

# Run sensitivity analysis
sensitivity = enhanced_model.sensitivity_analysis()
print("\nSensitivity Analysis Matrix:")
print(sensitivity)
# Out:
# Implied Share Price: $119.26
# Current Price: $254.23
# Upside/Downside: -53.1%
#
# ============================================================
# DCF VALUATION REPORT: AAPL
# ============================================================
#
# COMPANY INFORMATION
#    Ticker: AAPL
#    Sector: Technology
#    Industry: Consumer Electronics
#    Earnings Quality: good
#
# KEY ASSUMPTIONS
#    revenue_growth: 3.85%
#    op_margin: 30.44%
#    tax_rate: 16.81%
#    da_pct_rev: 2.88%
#    capex_pct_rev: 2.74%
#    nwc_pct_rev: 5.00%
#    terminal_growth: 2.50%
#    cost_debt: 6.00%
#    wacc: 8.62%
#
# VALUATION SUMMARY
#    Enterprise Value: $1813616.28M
#    Equity Value: $1750893.28M
#    Implied Share Price: $119.26
#    WACC: 8.62%
#    Current Price: $254.23
#    Upside/Downside: -53.1%
#
# ============================================================
# SENSITIVITY ANALYSIS - Price Target by WACC and Terminal Growth
# ============================================================
#
# Sensitivity Analysis Matrix:
#             6.6%        7.1%        7.6%        8.1%        8.6%        9.1%  \
# 1.0%  132.827108  121.599551  112.067279  103.873364   96.754502   90.512205
# 1.5%  145.286465  131.959916  120.809676  111.342962  103.205322    96.13528
# 2.0%  160.437472  144.339752  131.104392  120.030358   110.62826  102.546089
# 2.5%  179.258991   159.39407  143.405793  130.260316  119.261398  109.922994
# 3.0%      203.27  178.095488   158.36474  142.484345  129.427471  118.502601
# 3.5%  234.961734  201.953294  176.947695  157.349216  141.575173  128.605648
#
#             9.6%       10.1%       10.6%      11.1%
# 1.0%   84.994015   80.080888   75.678521  71.711237
# 1.5%   89.935726    84.45526   79.575665  75.203291
# 2.0%   95.524169   89.366748   83.923469   79.07693
# 2.5%  101.895501    94.92102   88.805135  83.398517
# 3.0%  109.226988    101.2534   94.325686  88.250751
# 3.5%  117.753779  108.540071  100.619628  93.738024

# %% [markdown]
# ### Todo
# Segment‑level forecasting if the company reports segments.
#
# Market Value for debt, Preferred Stocks, Non Controlling Interest
#
# Debt schedules and cash sweep for companies with complex capital structures.
#
# Pension and other post‑employment liabilities adjustments.
#
# Monte Carlo simulation for probabilistic valuation
